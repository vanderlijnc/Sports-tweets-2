# %% [markdown]
# ## Post-processing for the sports tweets
#
# - sportsn.csv is a csv file from main analysis running in cPouta containing the geoparsed tweets
# - geotaggedn.csv is a csv file from locally done analysis for geotagged tweets

# %% [markdown]
# ## Importing data

# %%
#import modules
import glob
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import folium
from folium.plugins import MarkerCluster
from pyproj import CRS

# %%
#read the geoparsed tweets to one gdf
names = []

geodf = gpd.GeoDataFrame()

for name in glob.glob(r"sports*.csv"):
    df = pd.read_csv(name)
    names.append(name)
    gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.lon, df.lat))
    geodf = geodf.append(gdf)

# %%
#delete the geocoded tweets from this df, they were handled separately
geodf = geodf[(geodf['geom'].isna())]
geodf
# Out:
#      Unnamed: 0                                          full_text geom  \
# 0            67  Trench run... #suomenlinna #fb http://t.co/MRE...  NaN
# 1          9033  I turned 40 years this week so I stretched tod...  NaN
# 2         10613  I wish it gets cold enough and the snow stays ...  NaN
# 3         11209  @aksalmi yep, it's not that far away this year...  NaN
# 4         11554  Celebrated 10.10.10 by running my third marath...  NaN
# ..          ...                                                ...  ...
# 271      490521      Kettu juoksi vastaan Eiranrannassa. #helsinki  NaN
# 272      495702  Oli HJK:lla paikkoja aikaisemminkin, mutta kyl...  NaN
# 273      496585  Eilen Helsingissä t-paita päällä. Tänään jalka...  NaN
# 274      498189  Osa näistä ruotsalaiskannattajista juoksee Hel...  NaN
# 275      194209  kõndisin mööda helsinkit ja keda ma nägin?! TA...  NaN
#
#                            geometry lang           lat  \
# 0    POINT (388272.705 6669477.595)   en  6.669478e+06
# 1    POINT (366700.059 6684680.631)   en  6.684681e+06
# 2    POINT (370853.565 6681537.224)   en  6.681537e+06
# 3    POINT (391713.120 6685777.801)   en  6.685778e+06
# 4    POINT (391713.120 6685777.801)   en  6.685778e+06
# ..                              ...  ...           ...
# 271  POINT (385446.347 6672081.187)   fi  6.672081e+06
# 272  POINT (385446.347 6672081.187)   fi  6.672081e+06
# 273  POINT (385446.347 6672081.187)   fi  6.672081e+06
# 274  POINT (385446.347 6672081.187)   fi  6.672081e+06
# 275  POINT (385446.347 6672081.187)   et  6.672081e+06
#
#                                             lemma_text  \
# 0     trench run ... suomenlinna fb http://t.co/mre...
# 1     I turn 40 year this week so I stretch today '...
# 2     I wish it get cold enough and the snow stay h...
# 3     @aksalmi yep , it 's not that far away this y...
# 4     celebrated 10.10.10 by run my third marathon ...
# ..                                                 ...
# 271         kettu juosta vastaan eiranranta . helsinki
# 272   olla HJK paikka aikaisemmin , mutta kylläpä s...
# 273   eilen Helsinki Tpaita päällä . tänään jalkapa...
# 274   osa tämä ruotsalaiskannattaja juosta Helsinki...
# 275   kõndima mööda helsinki ja kes mina nägema ? !...
#
#                                                 lemmas            lon
# 0    ['trench', 'run', '...', 'suomenlinna', 'fb', ...  388272.705362
# 1    ['I', 'turn', '40', 'year', 'this', 'week', 's...  366700.059287
# 2    ['I', 'wish', 'it', 'get', 'cold', 'enough', '...  370853.564617
# 3    ['@aksalmi', 'yep', ',', 'it', "'s", 'not', 't...  391713.120360
# 4    ['celebrated', '10.10.10', 'by', 'run', 'my', ...  391713.120360
# ..                                                 ...            ...
# 271  ['kettu', 'juosta', 'vastaan', 'eiranranta', '...  385446.347494
# 272  ['olla', 'HJK', 'paikka', 'aikaisemmin', ',', ...  385446.347494
# 273  ['eilen', 'Helsinki', 'Tpaita', 'päällä', '.',...  385446.347494
# 274  ['osa', 'tämä', 'ruotsalaiskannattaja', 'juost...  385446.347494
# 275  ['kõndima', 'mööda', 'helsinki', 'ja', 'kes', ...  385446.347494
#
# [7561 rows x 9 columns]

# %%
#import geotagged tweets 
for name in glob.glob(r"geotagged*.csv"):
    df = pd.read_csv(name)
    gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.lon, df.lat))
    #convert to epsg 3067 to match the crs of geoparsed tweets
    gdf.crs = CRS.from_epsg(4326)
    gdf = gdf.to_crs(3067)
    #append to geoparsed tweets
    geodf = geodf.append(gdf)
    #geodf.reset_index(inplace=True)

geodf
# Out:
#     Unnamed: 0                                          full_text  \
# 0           67  Trench run... #suomenlinna #fb http://t.co/MRE...
# 1         9033  I turned 40 years this week so I stretched tod...
# 2        10613  I wish it gets cold enough and the snow stays ...
# 3        11209  @aksalmi yep, it's not that far away this year...
# 4        11554  Celebrated 10.10.10 by running my third marath...
# ..         ...                                                ...
# 4            4  To #California it is. #business is going to #g...
# 5            5  #Repost elmobistro \n ···\nNew Seagulls table ...
# 6            6  Etätyössä parasta: sopivasti liikuntaa, tervee...
# 7            7  Urheilu ja musa #u20fi #Lauantai http://t.co/7...
# 8            8                                       Jääkiekkoa 😊
#
#                                                  geom  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 4   0101000020E6100000541B5A6CACCF38409A000D808222...
# 5   0101000020E6100000AC0C99E1F5EF3840B8CF85EC1716...
# 6   0101000020E61000003B40E6B974ED3840BFF51FA17F15...
# 7   0101000020E61000001E38252897083940CAB97FF29825...
# 8   0101000020E6100000113DC6685FCE38401417B280AA1C...
#
#                           geometry lang           lat  \
# 0   POINT (388272.705 6669477.595)   en  6.669478e+06
# 1   POINT (366700.059 6684680.631)   en  6.684681e+06
# 2   POINT (370853.565 6681537.224)   en  6.681537e+06
# 3   POINT (391713.120 6685777.801)   en  6.685778e+06
# 4   POINT (391713.120 6685777.801)   en  6.685778e+06
# ..                             ...  ...           ...
# 4   POINT (378924.860 6683445.954)   en  6.026961e+01
# 5   POINT (385562.235 6672421.377)   en  6.017261e+01
# 6   POINT (385003.328 6671920.931)   fi  6.016796e+01
# 7   POINT (391300.943 6685744.389)   fi  6.029373e+01
# 8   POINT (378474.802 6678372.585)   fi  6.022395e+01
#
#                                            lemma_text  \
# 0    trench run ... suomenlinna fb http://t.co/mre...
# 1    I turn 40 year this week so I stretch today '...
# 2    I wish it get cold enough and the snow stay h...
# 3    @aksalmi yep , it 's not that far away this y...
# 4    celebrated 10.10.10 by run my third marathon ...
# ..                                                ...
# 4    to # California it be . business be go to glo...
# 5    # repost elmobistro \n  ··· \n New seagull ta...
# 6    etätyö hyvä : sopivasti liikunta , terveellin...
# 7    urheilu ja musa u20fi # lauantai http://t.co/...
# 8                                         jääkiekko 😊
#
#                                                lemmas            lon
# 0   ['trench', 'run', '...', 'suomenlinna', 'fb', ...  388272.705362
# 1   ['I', 'turn', '40', 'year', 'this', 'week', 's...  366700.059287
# 2   ['I', 'wish', 'it', 'get', 'cold', 'enough', '...  370853.564617
# 3   ['@aksalmi', 'yep', ',', 'it', "'s", 'not', 't...  391713.120360
# 4   ['celebrated', '10.10.10', 'by', 'run', 'my', ...  391713.120360
# ..                                                ...            ...
# 4   ['to', '#', 'California', 'it', 'be', '.', 'bu...      24.811225
# 5   ['#', 'repost', 'elmobistro', '\n ', '···', '\...      24.937346
# 6   ['etätyö', 'hyvä', ':', 'sopivasti', 'liikunta...      24.927562
# 7   ['urheilu', 'ja', 'musa', 'u20fi', '#', 'lauan...      25.033556
# 8                                  ['jääkiekko', '😊']      24.806143
#
# [24507 rows x 9 columns]

# %% [markdown]
# ## Removing city geotags

# %%
def delete_city_geotags(geodf):
    """
    The posts tagged to a city geotag create artificial hotspots and should be removed for statistical analyses.
    
    Parameters:
    geodf| String: name of the geodataframe holding geocoded tweets
    """
    
    Helsinki_point = Point(385446.3474936858, 6672081.187213039)
    Espoo_point = Point(370853.5646174778, 6681537.223923998)
    Vantaa_point = Point(391713.1203601367, 6685777.800663358)
    
    geodf = geodf.drop(geodf[(geodf["geometry"]== Helsinki_point) | (geodf["geometry"]== Espoo_point) | (geodf["geometry"]== Vantaa_point)].index)
    
    geodf.reset_index(inplace= True)
    return geodf

# %%
citynames_del = delete_city_geotags(geodf)
citynames_del
# Out:
#        index  Unnamed: 0                                          full_text  \
# 0        324      398987  Lehmät käyttäytyy oudosti, tuijottavat ja sit ...
# 1        324      138819  Kuntosalille Hakunilan uimahalliin http://t.co...
# 2        379      451865  JES! Lauantaina Otaniemeen kattoo ku @WestendI...
# 3        383      452905  Edarin treenipelit jatkuvat. Tänään vastassa I...
# 4        384      452922  Vantaan Energia Areenasta EräViikinkien kotiha...
# ...      ...         ...                                                ...
# 14519   1341        1341  @rinsku82 tosi sitkeetä tauti. Itellä joulukuu...
# 14520   1342        1342  @rinsku82 Kiitos! Liikunnasta saa ainakin lisä...
# 14521   1343        1343  Fillari kaivettu kellarista ja kevään ensimmäi...
# 14522   1344        1344  Tämä on jalkapalloa - ei futista! Lajin kunink...
# 14523   1345        1345  @VesaSaarinen Vain ruotsalaiset voivat urheilu...
#
#                                                     geom  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14519  0101000020E6100000963F4241E7CF3840974362EDB520...
# 14520  0101000020E6100000BF62CBFAE6CF38401A47510CB520...
# 14521  0101000020E6100000E5BEEED711C6384043C0A58C4D1D...
# 14522  0101000020E6100000B5ADA0487BC63840C994EE32EC1F...
# 14523  0101000020E6100000AB313212EBEA3840F2E4E48F331B...
#
#                              geometry lang           lat  \
# 0      POINT (380887.070 6696292.263)   fi  6.696292e+06
# 1      POINT (395112.392 6683904.373)   fi  6.683904e+06
# 2      POINT (379530.879 6673879.195)   fi  6.673879e+06
# 3      POINT (392938.143 6677710.445)   fi  6.677710e+06
# 4      POINT (391713.120 6685777.801)   fi  6.685778e+06
# ...                               ...  ...           ...
# 14519  POINT (378922.596 6681879.486)   fi  6.025555e+01
# 14520  POINT (378922.264 6681876.507)   fi  6.025553e+01
# 14521  POINT (376697.344 6678986.700)   fi  6.022893e+01
# 14522  POINT (376863.270 6681262.225)   fi  6.024940e+01
# 14523  POINT (384609.887 6676898.557)   fi  6.021251e+01
#
#                                               lemma_text  \
# 0       lehmä käyttäytyy oudosti , tuijottaa ja sitte...
# 1       kuntosali hakunila uimahalli http://t.co/LhiM...
# 2       JES ! lauantai Otaniemi katto kun feestendind...
# 3       edari treenipeli jatkua . tänään vasta IHS . ...
# 4       Vantaa energia areena Eräviikinki kotihalli ....
# ...                                                  ...
# 14519   @rinsku82 tosi sitkee tauti . ittellä jouluku...
# 14520   @rinsku82 kiitos ! liikunta saada ainakin lis...
# 14521   fillari kaivaa kellari ja kevät ensimmäinen l...
# 14522   tämä olla jalkapallo - ei futti ! laji kunink...
# 14523   XVesasaarinen vain ruotsalainen voida urheilu...
#
#                                                   lemmas            lon
# 0      ['lehmä', 'käyttäytyy', 'oudosti', ',', 'tuijo...  380887.070009
# 1      ['kuntosali', 'hakunila', 'uimahalli', 'http:/...  395112.391609
# 2      ['JES', '!', 'lauantai', 'Otaniemi', 'katto', ...  379530.879264
# 3      ['edari', 'treenipeli', 'jatkua', '.', 'tänään...  392938.143094
# 4      ['Vantaa', 'energia', 'areena', 'Eräviikinki',...  391713.120360
# ...                                                  ...            ...
# 14519  ['@rinsku82', 'tosi', 'sitkee', 'tauti', '.', ...      24.812122
# 14520  ['@rinsku82', 'kiitos', '!', 'liikunta', 'saad...      24.812118
# 14521  ['fillari', 'kaivaa', 'kellari', 'ja', 'kevät'...      24.773710
# 14522  ['tämä', 'olla', 'jalkapallo', '-', 'ei', 'fut...      24.775319
# 14523  ['XVesasaarinen', 'vain', 'ruotsalainen', 'voi...      24.917649
#
# [14524 rows x 10 columns]

# %% [markdown]
# ## Saving sportslist to a column

# %%
sportslist_all = ["running", "run", "walk", "walking", "jog" ,"jogging", "hike", "hiking", "trek", "trekking", 
                  "bicycle", "bike", "biking","cycling", "exercise", "exercising", "ski", "skiing", "skate", "skating", 
                  "workout", "training", "sport", "sporting", "canoe", "canoeing", "ice-hockey", "basketball",
                 "hockey", "football", "tennis", "dance", "dancing", "rowing", "sweat", "sweating", "badminton",
                 "floorball", "volley", "volleyball",  "beach volley", "yoga","swimming", "swim", "sail", "sailing", "kayak", "kayaking", "squash", "tabletennis",
                "kävely", "kävellä", "käveleminen" "juoksu", "juosta", "juokseminen", "hiihto", "hiihtää", "hiihtäminen",
                 "lenkki", "lenkkeily", "lenkkeillä", "treenata", "treenaaminen", "urheilla", "meloa", "melonta", "soutaa", 
                 "soutaminen", "patikointi", "patikoida", "patikoiminen",  
                  "treeni", "urheilu", "liikunta", "pyörä", "pyöräily", "pyöräillä", "pyöräileminen", "jääkiekko", "hockey",
                  "jalkapallo", "tennis", "tanssi", "tanssia", "tanssiminen", "hiki", "hikoilla", "sulkapallo",
                     "sähly", "salibandy", "lentopallo",  "lentis", "luistella", "luisteleminen", "luistelu", "kuntosali",          
                 "koris","futis", "koripallo", "uinti", "uida", "uiminen", "kajakki", "pujehtia", 
                 "purjehdus", "lätkä", "jooga", "squash", "kössi", "pingis", "pöytätennis","jooksmine", "jooksma", 
                 "jooks", "kõndimine", "kõnd", "kõndima", "jalutama", "jalutus", 
                 "jalutamine", "sörkimine", "sörkima", "sörk", "sörksjooks", "matk", "matkamine", "matkama",
                   "jalgratas", "jalgrattasõit", "rattasõit", "treening", "treenima", "võimlema", "võimlemine", 
                 "uisutamine", "uisutama", "suusatama", "suusatamine", "sportima", "sportimine", "trenn", "sport", 
                 "jõusaal", "võimla", "spordihall", "spordisaal", "korvpall", "koss", "kanuu",  "kanuutama", 
                 "kanuutamine", "kanuusõit", "jäähoki", "hoki", "jalgpall", "jalka", "tennis", "tants", 
                 "tantsimine", "tantsima", "sõudmine", "sõudma", "aerutama", "aerutamine", "higi", "higistama", 
                 "higistamine", "sulgpall", "bädminton", "saalihoki", "volle", "rannavolle", "võrkpall", 
                 "rannavõrkpall", "joogatama", "jooga", "ujuma", "ujumine", "meresüst",  "kajakisõit", "purjetama", 
                 "purjetamine", "squash", "seinatennis", "lauatennis"]
   

    
for i, row in geodf.iterrows():
    try:
        sports_list= [lemma for lemma in geodf["lemmas"][i] if(lemma in sportslist_all)]
        geodf["sports"][i] = sports_list
        
    except KeyError:
        print("avainerrori")
        
geodf

# %% [markdown]
# ## OLS testing
#
# - this will be done with a separate R script

# %%
import pandas.plotting
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn


data = gpd.read_file(r"Geotag_pip.shp")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-b30f9b19c166> in <module>()
#       1 import pandas.plotting
# ----> 2 import statsmodels.api as sm
#       3 from statsmodels.formula.api import ols
#       4 import matplotlib.pyplot as plt
#       5 import seaborn
#
# /Users/kosokoso/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/statsmodels/api.py in <module>()
#       7 from . import tools
#       8 from .tools.tools import add_constant, categorical
# ----> 9 from . import regression
#      10 from .regression.linear_model import OLS, GLS, WLS, GLSAR
#      11 from .regression.recursive_ls import RecursiveLS
#
# /Users/kosokoso/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/statsmodels/regression/__init__.py in <module>()
# ----> 1 from .linear_model import yule_walker
#       2
#       3 from statsmodels.tools._testing import PytestTester
#       4
#       5 __all__ = ['yule_walker', 'test']
#
# /Users/kosokoso/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in <module>()
#      38 import numpy as np
#      39 from scipy.linalg import toeplitz
# ---> 40 from scipy import stats
#      41 from scipy import optimize
#      42
#
# /Users/kosokoso/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/scipy/stats/__init__.py in <module>()
#     365 from __future__ import division, print_function, absolute_import
#     366
# --> 367 from .stats import *
#     368 from .distributions import *
#     369 from .morestats import *
#
# /Users/kosokoso/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/scipy/stats/stats.py in <module>()
#     170 from scipy._lib._version import NumpyVersion
#     171 from scipy._lib._util import _lazywhere
# --> 172 import scipy.special as special
#     173 from . import distributions
#     174 from . import mstats_basic
#
# /Users/kosokoso/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/scipy/special/__init__.py in <module>()
#     639 from .sf_error import SpecialFunctionWarning, SpecialFunctionError
#     640
# --> 641 from ._ufuncs import *
#     642
#     643 from .basic import *
#
# ImportError: dlopen(/Users/kosokoso/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/scipy/special/_ufuncs.cpython-37m-darwin.so, 2): Library not loaded: @rpath/libgfortran.3.dylib
#   Referenced from: /Users/kosokoso/opt/anaconda3/envs/nlp/lib/python3.7/site-packages/scipy/special/_ufuncs.cpython-37m-darwin.so
#   Reason: image not found

# %%
data.drop([0], axis=0, inplace=True)
pandas.plotting.scatter_matrix(data[['NUMPOINTS', 'NUMfacilit', 'mediaanitu', "hi_edu"]])

# %%
model = ols("NUMPOINTS ~ NUMfacilit", data).fit()
print(model.summary())

# %%
seaborn.pairplot(data, vars=['NUMPOINTS', 'NUMfacilit'],kind='reg')
seaborn.lmplot(y='NUMPOINTS', x='NUMfacilit', data=data)

# %%
stdres = pd.DataFrame(model.resid_pearson)
plt.plot(stdres, 'o', ls = 'None')
l = plt.axhline(y=0, color = 'r')
